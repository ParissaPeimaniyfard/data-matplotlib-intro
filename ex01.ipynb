# %% [markdown]
# # Matplotlib Introduction
#
# Today's first orders of business:
# 1. Plot a point
# 1. Plot multiple points
# 1. Plot a line
# 1. Plot multiple curves

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Plot a Point
#
# Plot a dot at **x=5** and **y=10**
#
# Remember that you have the `pyplot.scatter()` [documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter.).

# %%
x_point=[5]
y_point=[10]
plt.scatter(x_point, y_point, edgecolors= '#f0b000', alpha=1);

# %% [markdown]
# ## Plot Multiple Points
#
# Plot several dots stored in a list of **dimensions (2, 13)** (meaning a list of lists)

# %%
#list= [[1,4,6,8,5,4,5,7,9,1,3,2,4], [5,6,8,9,2,1,6,5,4,2,7,6,8]]
x_points= list[0]
y_points= list[1]
plt.scatter(x_points, y_points, marker='o', edgecolors= '#f08070');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 4
#       2 x_points= list[0]
#       3 y_points= list[1]
# ----> 4 plt.scatter(x_points, y_points, marker='o', edgecolors= '#f08070')
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/pyplot.py:2817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2812 @_copy_docstring_and_deprecators(Axes.scatter)
#    2813 def scatter(
#    2814         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2820         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2821         **({"data": data} if data is not None else {}), **kwargs)
#    2822     sci(__ret)
#    2823     return __ret
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4457, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4451         linewidths = [
#    4452             lw if lw is not None else rcParams['lines.linewidth']
#    4453             for lw in linewidths]
#    4455 offsets = np.ma.column_stack([x, y])
# -> 4457 collection = mcoll.PathCollection(
#    4458         (path,), scales,
#    4459         facecolors=colors,
#    4460         edgecolors=edgecolors,
#    4461         linewidths=linewidths,
#    4462         offsets=offsets,
#    4463         transOffset=kwargs.pop('transform', self.transData),
#    4464         alpha=alpha
#    4465         )
#    4466 collection.set_transform(mtransforms.IdentityTransform())
#    4467 collection.update(kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/collections.py:1012, in PathCollection.__init__(self, paths, sizes, **kwargs)
#     998 def __init__(self, paths, sizes=None, **kwargs):
#     999     """
#    1000     Parameters
#    1001     ----------
#    (...)
#    1009         Forwarded to `.Collection`.
#    1010     """
# -> 1012     super().__init__(**kwargs)
#    1013     self.set_paths(paths)
#    1014     self.set_sizes(sizes)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/collections.py:196, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     193     self._joinstyle = None
#     195 if offsets is not None:
# --> 196     offsets = np.asanyarray(offsets, float)
#     197     # Broadcast (2,) -> (1, 2) but nothing else.
#     198     if offsets.shape == (2,):
#
# TypeError: float() argument must be a string or a real number, not 'types.GenericAlias'

# %% [markdown]
# ## Plotting a Line
#
# Plot a line starting at **x=4, y=0** and ending at **x=20, y=4**. The function you should use is [pyplot.plot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)

# %%
x=[4,20]
y=[0,4]
plt.plot(x,y,'o' ':' 'm')

# %% [markdown]
# ## Plotting Multiple Curves
#
# Plot 3 different curves on the same graph, still with pyplot.plot().

# %%
x=[1,5,7,9]
y1=[3,6,8,9]
y2=[3,1,5,7]
y3=[4,7,6,9]
plt.plot(x,y1 , 'g');
plt.plot(x,y2 , 'r');
plt.plot(x,y3 , 'm');

# %% [markdown]
# ## 🧪 Test your Knowledge

# %% [markdown]
# **QUIZ**

# %% [markdown]
# ❓Which `matplotlib.pyplot` method should you use to represent a continuous function such as $y=3x^2+1$?
#
# Define a variable `continuous_function_method` with the correct response (a or b)

# %%
continuous_function_method= b

a = 'scatter()'
b = 'plot()'

# %% [markdown]
# ❓Which `matplotlib.pyplot` method should you use to represent the relationship between 2 variables such as _age_ and _height_?
#
# Define a variable `relationship_method` with the correct response (a or b)

# %%
a = 'scatter()'
b = 'plot()'
relationship_method= a

# %% [markdown]
# Run the following cell to check your answers

# %%
from nbresult import ChallengeResult

result = ChallengeResult('quiz', answer1=continuous_function_method, answer2=relationship_method)
result.write()
print(result.check())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 3
#       1 from nbresult import ChallengeResult
# ----> 3 result = ChallengeResult('quiz', answer1=continuous_function_method, answer2=relationship_method)
#       4 result.write()
#       5 print(result.check())
#
# NameError: name 'relationship_method' is not defined

# %% [markdown]
# ## 🏁 Push your challenge
#
# Please to commit and push your challenge on GitHub 👍
